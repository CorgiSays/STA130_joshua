# %% [markdown]
# # STATS Tutorial Homework

# %% [markdown]
# TUTORIAL TRANSCRIPT https://chatgpt.com/share/7f23c00b-a60b-4918-b77e-4e08d7b33589

# %% [markdown]
# HOMEWORK TRANSCRIPT https://chatgpt.com/share/0efdec9f-3b6f-47c7-a250-fe695640168e

# %%
import pandas as pd

# URL of the dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# Load the dataset into a DataFrame
df = pd.read_csv(url)
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["num missing"] = df.isna().s sum(axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()[:15][['Name','Survived']]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Get the number of rows and columns
rows, columns = df.shape

# Print the results
print(f'The data frame has {rows} rows and {columns} columns.')
# Out:
# The data frame has 891 rows and 13 columns.

# %% [markdown]
# As stated by ChatGPT, but reworded into my own thinking, the way that the observations and variables work in the context of this dataset is as follows;

# %% [markdown]
# A variable represents the entire dataset, but on one specific topic, for example, the passenger's name, or their class.
#
# An observation represents one specific passenger, whether it be Mrs Jacques Heath on row 3 or Mr Timothy J on Row 6. It is the combination of all the variables, but all referencing a single individual.

# %%
# Summary of numeric columns
print(df.describe())

# Summary of all columns (including non-numeric)
print(df.describe(include='all'))
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  num missing
# count  891.000000  891.000000   891.000000
# mean     0.381594   32.204208     0.971942
# std      0.806057   49.693429     0.618351
# min      0.000000    0.000000     0.000000
# 25%      0.000000    7.910400     1.000000
# 50%      0.000000   14.454200     1.000000
# 75%      0.000000   31.000000     1.000000
# ...

# %% [markdown]
# It can be noted that in a handful of variables, the count is severely under the 891 expected for one per observation. This is due to null values being omitted. In this case, if there is missing data, the observation will be omitted when calculating various aspects like the mean, std, min, etc and the count will be lowered.
#
# Another thing to note is that the first iteration of this code will only take numeric values into calculation, whereas the second iteration will take ALL data, including non numeric. For numerical values, we should utilize the top one, however, for information like the number of males compared to females, which was provided in the form of "male" "female" statistics (strings), you can look at the "include='all'" iteration of the code.
#
# The difference between an attribute and a method is as follows;
#
# - An attribute is effectively data that is already in the object, in a reference to Python Classes, it would be something that requires no calculation and can be obtained by simply getting the variable name.
#
# - A method is a function, it is data that requires calculation and can potentially have parameters passed through it. For example, in the above code, df.describe() uses an argument of "include='all'", which tells the method to also include the non numeric data and work with it as though it were numeric data.

# %% [markdown]
# # POST LECTURE HOMEWORK

# %% [markdown]
# #6 - The df.describe() method provides the 'count','mean','std','min',etc summary for each variable;
#
# - Count represents the number of items accounted for in the calculations below. It will omit missing values as they are not used to calculate any of the data below.
#
# #7 - dropna() will delete any rows which may have missing data, this is useful if you require all of your data to be complete, or if you're doing a stats assignment where your professor wants you to work without missing data.
#
# However, if a lot of the data is missing in a handful of columns, you can del df['col'] to delete an entire column in question. For example in the titanic dataset, it is shown that there are only 204 observations where cabin is not n/a. If we dropna'd, all but 204 rows would be deleted, drastically reducing the dataset size. In this case, if we don't need the cabin data, we can del df['col'] to just remove the Cabin variable.
#
# In another scenario, if we want to remove all N/A rows, EXCEPT for those which are exclusively N/A in the Age category, we can delete the Age category first, then dropna. This is just one use case where it may allow you to preserve more data than dropna() while still allowing you to have a complete dataset.
#
# In the next line of the code, I will be dropping the Cabin line of code, then dropna'ing. This will remove any observations that are missing information other than the cabin number. This is because the cabin variable is already incredibly limited, only having 200 observations, as such, dropna'ing with it still in the dataset will remove all but 200 of our rows.

# %%
del df['Cabin']
df = df.dropna()

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# This is question #8, and below is the import for the dataset. Please refresh the kernel before running this.

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ChatGPT broke down the groupby expression, but did not give an example. The following will be my usage of the entire groupby()[].describe() function.

# %%
df.groupby("survived")["fare"].describe()
# Out:
#           count       mean        std  min      25%   50%   75%       max
# survived
# 0         549.0  22.117887  31.388207  0.0   7.8542  10.5  26.0  263.0000
# 1         342.0  48.395408  66.596998  0.0  12.4750  26.0  57.0  512.3292

# %% [markdown]
# Not at all related to the assignment, but the average person who survived paid over twice as much on their fare as those who did not survive. This makes a lot of sense, as the first class passengers of the Titanic were likely the first ones to get access to a lifeboat.
#
# 2. The count line of the data in this case includes null values. In the df.groupby expression, all null values are still accounted for (but just ignored). However, in the following line, I will run the same code after running df.dropna().

# %%
df = df.dropna()
df.groupby("survived")["fare"].describe()
# Out:
#           count       mean        std   min    25%      50%   75%       max
# survived
# 0          59.0  64.532131  62.108090  0.00  27.15  50.4958  79.2  263.0000
# 1         123.0  85.821107  81.843522  8.05  30.50  69.3000  93.5  512.3292

# %% [markdown]
# As there is significantly less data (most of the data was dropped due to missing values), the count is significantly lower, as well as the rest of the data. It is shown here that generally, the richer passengers were more reported on, and as such had less missing data.
#
# In the next line of the code, I will intentionally implement errors into the code as requested by question #3.

# %%
# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
#       4 # Download and load the dataset into a pandas DataFrame
# ----> 5 df = pd.read_csv(url)
#       7 # Display the first few rows of the dataset
#       8 print(df.head())
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanics.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanics.csv"
#       6 # Download and load the dataset into a pandas DataFrame
# ----> 7 df = pd.read_csv(url)
#       9 # Display the first few rows of the dataset
#      10 print(df.head())
#
# ...

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(DF.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7 df = pd.read_csv(url)
#       9 # Display the first few rows of the dataset
# ---> 10 print(DF.head())
#
# NameError: name 'DF' is not defined

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url

# Display the first few rows of the dataset
print(df.head())
# Out:
#   Cell In[4], line 7
#     df = pd.read_csv(url
#                     ^
# SyntaxError: '(' was never closed

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.hed())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_118/1316530229.py in ?()
#       6 # Download and load the dataset into a pandas DataFrame
#       7 df = pd.read_csv(url)
#       8
#       9 # Display the first few rows of the dataset
# ---> 10 print(df.hed())
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'hed'

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.head())

df.groupby("Age")["class"].describe()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 12
# ...

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.head())

df.groupby("age")[pclass].describe()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
# ...

# %%
import pandas as pd

# URL for the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"

# Download and load the dataset into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataset
print(df.head())

# Group by 'age' and describe 'pclass'
grouped = df.groupby("age")["pclass"].describe()
print(grouped)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#        count  mean       std  min   25%  50%   75%  max
# age
# 0.42     1.0   3.0       NaN  3.0  3.00  3.0  3.00  3.0
# 0.67     1.0   2.0       NaN  2.0  2.00  2.0  2.00  2.0
# ...

# %% [markdown]
# A google search is significantly easier than asking chatgpt. Additionally, a lot of these errors could be deciphered purely off of the error message itself, for stuff such as "missing parenthesis", etc. I also started feeling bad for chatgpt as it kept giving me the correct code and I had to keep messing it up to send it back.

# %% [markdown]
# https://chatgpt.com/share/6e270a4f-d4c0-46b9-a799-53503d32f821

# %% [markdown]
# 9. Somewhat? Perhaps?
